# %% [markdown]
# <a href="https://colab.research.google.com/github/omergul2005/yapay-zeka-proje-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os
import zipfile
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Dosya adını 'archive.zip' olarak güncelledik
zip_yolu = '/content/drive/MyDrive/archive.zip'
cikarilacak_yer = '/content/dataset'

if not os.path.exists(cikarilacak_yer):
    with zipfile.ZipFile(zip_yolu, 'r') as zip_ref:
        zip_ref.extractall(cikarilacak_yer)
    print("Zıp dosyası başarıyla açıldı.")
else:
    print("Dosyalar zaten mevcut.")

# Kaggle'dan inen dosyalarda genelde içeriden 'chest_xray' klasörü çıkar.
# Bu yolları kontrol etmek için Colab sol menüdeki dosya simgesine bakabilirsin.
train_path = '/content/dataset/chest_xray/train'
test_path = '/content/dataset/chest_xray/test'
# Out:
# Zıp dosyası başarıyla açıldı.

# %%
# Eğitim için artırma, Test için sadece ölçeklendirme
train_gen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(train_path, target_size=(150, 150), batch_size=32, class_mode='binary')
test_data = test_gen.flow_from_directory(test_path, target_size=(150, 150), batch_size=32, class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Modeli tanımlamadan önce bu satırı mutlaka ekleyin
model = Sequential()

# 1. Evrişim ve Havuzlama
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D(2, 2))

# 2. Evrişim ve Havuzlama
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

# 3. Evrişim ve Havuzlama (Hocanın şartı için bir tane daha ekledik)
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

# Sınıflandırma Katmanları
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid')) # İkili sınıflandırma (Zatürre vs Normal) için 1 nöron ve sigmoid idealdir.

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ...

# %%
history = model.fit(train_data,
                    epochs=10,
                    validation_data=test_data)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 461ms/step - accuracy: 0.7770 - loss: 0.5177 - val_accuracy: 0.8542 - val_loss: 0.3491
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 74s 452ms/step - accuracy: 0.8885 - loss: 0.2761 - val_accuracy: 0.8109 - val_loss: 0.4566
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 72s 440ms/step - accuracy: 0.9027 - loss: 0.2308 - val_accuracy: 0.7949 - val_loss: 0.4569
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 73s 449ms/step - accuracy: 0.9069 - loss: 0.2279 - val_accuracy: 0.8670 - val_loss: 0.3380
# Epoch 5/10
# ...

# %%
# Grafikleri çizdir
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Eğitim')
plt.plot(history.history['val_accuracy'], label='Test')
plt.title('Doğruluk Grafiği')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Eğitim')
plt.plot(history.history['val_loss'], label='Test')
plt.title('Kayıp Grafiği')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Test verileri üzerinden tahmin yap
test_data.reset()
Y_pred = model.predict(test_data)
y_pred = (Y_pred > 0.5).astype(int)
y_true = test_data.classes

# Matrisi hesapla
cm = confusion_matrix(y_true, y_pred)

# Görselleştir
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues',
            xticklabels=['Normal', 'Zaturre'],
            yticklabels=['Normal', 'Zaturre'])
plt.title('Şekil 4: Karışıklık Matrisi')
plt.ylabel('Gerçek Değer')
plt.xlabel('Tahmin Edilen')
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step

# %%
import tensorflow as tf

# dpi değerini 150 yaparak yazıları büyütüyoruz
# rankdir='TB' yaparak dikey (yukarıdan aşağı) yapıyoruz, böylece yazılar sıkışmaz
tf.keras.utils.plot_model(model,
                          to_file='model_net_diyagram.png',
                          show_shapes=True,
                          show_layer_names=False, # İsimleri kapatıp alanı genişletiyoruz
                          rankdir='TB',
                          dpi=150)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Resim yollarını klasör yapına göre kontrol et
normal_ornek = train_path + '/NORMAL/' + os.listdir(train_path + '/NORMAL')[0]
zaturre_ornek = train_path + '/PNEUMONIA/' + os.listdir(train_path + '/PNEUMONIA')[0]

plt.figure(figsize=(12, 6))

# Normal Röntgen
plt.subplot(1, 2, 1)
img_normal = mpimg.imread(normal_ornek)
plt.imshow(img_normal, cmap='gray')
plt.title('Örnek: Normal Akciğer')
plt.axis('off')

# Zatürre Röntgen
plt.subplot(1, 2, 2)
img_zaturre = mpimg.imread(zaturre_ornek)
plt.imshow(img_zaturre, cmap='gray')
plt.title('Örnek: Zatürre (Pneumonia)')
plt.axis('off')

plt.show()

# %% [markdown]
#  Örnek Görüntüler Şekil 1'de görüldüğü üzere, normal akciğer röntgenlerinde akciğer alanları daha siyah (şeffaf) görünürken, zatürre (pneumonia) vakalarında iltihaplanma ve sıvı birikmesi nedeniyle beyazımsı, bulanık (opak) alanlar dikkat çekmektedir. Modelimiz bu piksellerdeki yoğunluk farklarını analiz ederek sınıflandırma yapmaktadır.
#  Normal Görüntü Örnekleri: Sağlıklı bir akciğer röntgeninde akciğer sahaları daha temiz, siyah (hava dolu) ve damar yapıları belirgindir.
#
# Zatürre (Pneumonia) Görüntü Örnekleri: Bu görüntülerde ise akciğer dokusu üzerinde beyazlaşmalar (opasite), iltihaplanma kaynaklı buzlu cam manzarası ve bulanıklıklar görülmektedir.
#
# Şekil 1: Veri kümesinde yer alan Normal (Sol) ve Zatürre (Sağ) sınıflarına ait örnek röntgen görüntüleri.

# %% [markdown]
# 3.2 Model Özeti (Kod çıktına göre)
# Toplam katman sayısı: 11 (Giriş, 3 Conv, 3 Pool, Flatten, 2 Dense, 1 Dropout)
#
# Evrişim katmanı sayısı: 3
#
# Havuzlama katmanı sayısı: 3
#
# Düzenlileştirme katmanları: BatchNormalization ve Dropout
#
# Toplam eğitilebilir parametre: 19,033,409
